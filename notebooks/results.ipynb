# %% [markdown]
# # Results Analysis
#
# Compare feature selection methods across datasets, models, and k.

# %%
import pandas as pd
from pathlib import Path

results = pd.read_csv(Path.cwd().parent / 'results' / 'metrics.csv')
results.head()
